# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)

# %%
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = "Times New Roman"

# %%
df1=pd.read_excel('data/Breachformationtime/WSEmax1.xlsx')

# %%
df1.head()
# Out:
#    SN  Station (m)         A         B         C         D         E         F
# 0   1        0.000  1456.717  1455.626  1454.608  1453.712  1452.841  1401.486
# 1   2        0.684  1456.732  1455.642  1454.625  1453.728  1452.857  1401.398
# 2   3        3.223  1456.708  1455.618  1454.601  1453.705  1452.832  1401.342
# 3   4        4.368  1456.642  1455.553  1454.535  1453.638  1452.766  1401.212
# 4   5        8.245  1456.347  1455.257  1454.237  1453.338  1452.464       NaN

# %%
df1.head(500
        )
# Out:
#       SN  Station (m)         A         B         C         D         E  \
# 0      1        0.000  1456.717  1455.626  1454.608  1453.712  1452.841
# 1      2        0.684  1456.732  1455.642  1454.625  1453.728  1452.857
# 2      3        3.223  1456.708  1455.618  1454.601  1453.705  1452.832
# 3      4        4.368  1456.642  1455.553  1454.535  1453.638  1452.766
# 4      5        8.245  1456.347  1455.257  1454.237  1453.338  1452.464
# ..   ...          ...       ...       ...       ...       ...       ...
# 495  496      518.934       NaN       NaN       NaN       NaN       NaN
# 496  497      518.934       NaN       NaN       NaN       NaN       NaN
# 497  498      522.469  1415.698  1414.766  1413.901  1413.079  1412.311
# 498  499      522.469       NaN       NaN       NaN       NaN       NaN
# 499  500      526.215  1415.575  1414.644  1413.780  1412.959  1412.191
#
#             F
# 0    1401.486
# 1    1401.398
# 2    1401.342
# 3    1401.212
# 4         NaN
# ...

# %%
df1= df1.interpolate()

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
# without interpolate
plt.figure(figsize=(10,6))
plt.plot(df1["Station (m)"],df1["A"],label="Breach Formation Time 0.1 WSE Max")
plt.plot(df1["Station (m)"],df1["B"],label="Breach Formation Time 0.15 WSE Max")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df1["C"],label="Breach Formation Time 0.2 WSE Max")
plt.plot(df1["Station (m)"],df1["D"],label="Breach Formation Time 0.25 WSE Max")
plt.plot(df1["Station (m)"],df1["E"],label="Breach Formation Time 0.3 WSE Max")
plt.plot(df1["Station (m)"],df1["F"],label="Terrain Profile")
# grid
plt.grid(b=True)
# label
plt.title("Water Surface Elevation 'River_Centerline' ",fontweight="bold")
plt.ylabel('Meters')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/Breachformationtime/1wsemax.jpg',dpi=300)

# %%
# with interpolate
plt.figure(figsize=(10,6))
plt.plot(df1["Station (m)"],df1["A"],label="Breach Formation Time 0.1 WSE Max")
plt.plot(df1["Station (m)"],df1["B"],label="Breach Formation Time 0.15 WSE Max")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df1["C"],label="Breach Formation Time 0.2 WSE Max")
plt.plot(df1["Station (m)"],df1["D"],label="Breach Formation Time 0.25 WSE Max")
plt.plot(df1["Station (m)"],df1["E"],label="Breach Formation Time 0.3 WSE Max")
plt.plot(df1["Station (m)"],df1["F"],label="Terrain Profile")
# grid
plt.grid(b=True)
# label
plt.title("Water Surface Elevation 'River_Centerline' ",fontweight="bold")
plt.ylabel('Water Surface Elevation(meters)')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/Breachformationtime/wsemax.jpg',dpi=300)

# %%
# breachwidth
df2=pd.read_excel('data/BreachWidth/WSE1.xlsx')

# %%
df2.head()
# Out:
#    SN  Station(m)         A         B         C         D         E         F
# 0   1       0.000  1453.618  1450.626  1446.945  1441.933  1431.125  1401.486
# 1   2       0.684  1453.618  1450.629  1446.953  1441.951  1431.138  1401.398
# 2   3       3.223  1453.558  1450.574  1446.906  1441.925  1431.085  1401.342
# 3   4       4.368  1453.495  1450.508  1446.835  1441.851  1430.996  1401.212
# 4   5       8.245  1453.228  1450.226  1446.528  1441.517  1430.604       NaN

# %%
df2= df2.interpolate()

# %%
df2.head()
# Out:
#    SN  Station(m)         A         B         C         D         E         F
# 0   1       0.000  1453.618  1450.626  1446.945  1441.933  1431.125  1401.486
# 1   2       0.684  1453.618  1450.629  1446.953  1441.951  1431.138  1401.398
# 2   3       3.223  1453.558  1450.574  1446.906  1441.925  1431.085  1401.342
# 3   4       4.368  1453.495  1450.508  1446.835  1441.851  1430.996  1401.212
# 4   5       8.245  1453.228  1450.226  1446.528  1441.517  1430.604  1401.159

# %%
# with interpolate
plt.figure(figsize=(10,6))
plt.plot(df2["Station(m)"],df2["A"],label="Dam Breach Width 247.5 WSE Max")
plt.plot(df2["Station(m)"],df2["B"],label="Dam Breach Width 198 WSE Max")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df2["Station(m)"],df2["C"],label="Dam Breach Width 148.5 WSE Max")
plt.plot(df2["Station(m)"],df2["D"],label="Dam Breach Width 99 WSE Max")
plt.plot(df2["Station(m)"],df2["E"],label="Dam Breach Width 48.5 WSE Max")
plt.plot(df2["Station(m)"],df2["F"],label="Terrain Profile")
# grid
plt.grid(b=True)
# label
plt.title("Water Surface Elevation 'River_Centerline' ",fontweight="bold")
plt.ylabel('Water Surface Elevation(meters)')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/BreachWidth/wsemax.jpg',dpi=300)

# %%
# Dambreachelevation
df3=pd.read_excel('data/Dambreachelevation/WSEmax1.xlsx')

# %%
df3.head()
# Out:
#    SN  Station (m)         A         B         C         D         E         F
# 0   1        0.000  1450.228  1451.031  1451.728  1452.901  1453.542  1401.486
# 1   2        0.684  1450.241  1451.044  1451.742  1452.917  1453.558  1401.398
# 2   3        3.223  1450.207  1451.011  1451.710  1452.893  1453.534  1401.342
# 3   4        4.368  1450.138  1450.943  1451.642  1452.827  1453.468  1401.212
# 4   5        8.245  1449.831  1450.636  1451.337  1452.530  1453.169       NaN

# %%
df3=df3.interpolate()

# %%
# with interpolate
df3=df3.interpolate()
# plot
plt.figure(figsize=(10,6))
plt.plot(df3["Station (m)"],df3["A"],label="Dam Breach Elevation 1580 WSE Max")
plt.plot(df3["Station (m)"],df3["B"],label="Dam Breach Elevation 1582 WSE Max")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df3["Station (m)"],df3["C"],label="Dam Breach Elevation 1584 WSE Max")
plt.plot(df3["Station (m)"],df3["D"],label="Dam Breach Elevation 1586 WSE Max")
plt.plot(df3["Station (m)"],df3["E"],label="Dam Breach Elevation 1588 WSE Max")
plt.plot(df3["Station (m)"],df3["F"],label="Terrain Profile")
# grid
plt.grid(b=True)
# label
plt.title("Water Surface Elevation 'River_Centerline' ",fontweight="bold")
plt.ylabel('Water Surface Elevation(meters)')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/Dambreachelevation/wsemax.jpg',dpi=300)

# %%
# Weircoefficient
df4= pd.read_excel('data/Weircoefficient/WSEmax1.xlsx')

# %%
df4.head()
# Out:
#    SN  Station (m)         A         B         C         D         E         F
# 0   1        0.000  1456.129  1453.145  1453.928  1454.686  1455.418  1401.486
# 1   2        0.684  1456.146  1453.161  1453.945  1454.703  1455.435  1401.398
# 2   3        3.223  1456.125  1453.137  1453.921  1454.680  1455.413  1401.342
# 3   4        4.368  1456.060  1453.070  1453.855  1454.614  1455.347  1401.212
# 4   5        8.245  1455.763  1452.769  1453.555  1454.316  1455.050       NaN

# %%
# with interpolate
df4=df4.interpolate()
# range

# plot
plt.figure(figsize=(10,6))
plt.plot(df4["Station (m)"],df4["A"],label="Weir coefficient 3 WSE Max")
plt.plot(df4["Station (m)"],df4["B"],label="Weir coefficient 2.6 WSE Max")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df4["Station (m)"],df4["C"],label="Weir coefficient 2.7 WSE Max")
plt.plot(df4["Station (m)"],df4["D"],label="Weir coefficient 2.8 WSE Max")
plt.plot(df4["Station (m)"],df4["E"],label="Weir coefficient 2.9 WSE Max")
plt.plot(df4["Station (m)"],df4["F"],label="Terrain Profile")
# grid
plt.grid(b=True)
# label
plt.title("Water Surface Elevation 'River_Centerline' ",fontweight="bold")
plt.ylabel('Water Surface Elevation(meters)')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/Weircoefficient/wsemax.jpg',dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11880/3957967830.py in <module>
#       1 # with interpolate
# ----> 2 df4=df4.interpolate()
#       3 # range
#       4 plt.ylim(top=1500)
#       5 # plot
#
# NameError: name 'df4' is not defined

# %%
# basecase
df5= pd.read_excel('data/baseCase/MaxWSEonriverprof1.xlsx')

# %%
df5.head()
# Out:
#    SN  Station(m)         A         B
# 0   1       0.000  1453.712  1401.486
# 1   2       0.684  1453.728  1401.398
# 2   3       3.223  1453.705  1401.342
# 3   4       4.368  1453.638  1401.212
# 4   5       8.245  1453.338       NaN

# %%
# with interpolate
df5=df5.interpolate()

# range

# plot
plt.figure(figsize=(10,6))
plt.plot(df5["Station(m)"],df5["A"],label="WSE'Max'")
plt.plot(df5["Station(m)"],df5["B"],label="Terrain profiles")
plt.ylim(top=1500)

# grid
plt.grid(b=True)
# label
plt.title("Water Surface Elevation 'River_Centerline' ",fontweight="bold")
plt.ylabel('Water Surface Elevation(meters)')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/basecase/wsemax.jpg',dpi=300)
