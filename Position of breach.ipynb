# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = "Times New Roman"
figure(figsize=(8, 6), dpi=80)

# %%
# velocity
df1=pd.read_excel('data/position of breach/Velocity1.xlsx')

# %%
df1.head(500)
# Out:
#       SN  Station (m)       A       B       C
# 0      1        0.000  26.306  59.835  58.628
# 1      2        0.684  26.528  59.467  59.098
# 2      3        3.223  27.507  57.615  60.284
# 3      4        4.368  28.033  56.525  60.427
# 4      5        8.245  29.790  53.208  60.663
# ..   ...          ...     ...     ...     ...
# 495  496      853.366  44.732  44.728  44.735
# 496  497      853.908  44.765  44.760  44.768
# 497  498      856.431  44.950  44.945  44.953
# 498  499      856.986  44.999  44.995  45.002
# 499  500      857.853  45.083  45.078  45.086
#
# [500 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
plt.plot(df1["Station (m)"],df1["A"],label="Position Left Max Velocity")
plt.plot(df1["Station (m)"],df1["B"],label="Position Right Max Velocity")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df1["C"],label="Position Center Max Velocity")
# grid
plt.grid(b=True)
# label
plt.title("Velocity on 'River_Centerline' ",fontweight="bold")
plt.ylabel('Velocity Max (m/s)')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/position of breach/velocity.jpg',dpi=300)

# %%
# wse
df2=pd.read_excel('data/position of breach/WSE1.xlsx')
df2.head()
# Out:
#    SN  Station (m)         A         B         C         D
# 0   1        0.000  1431.934  1435.127  1436.161  1401.486
# 1   2        0.684  1431.945  1435.100  1436.169  1401.398
# 2   3        3.223  1431.975  1434.894  1436.115  1401.342
# 3   4        4.368  1431.984  1434.750  1436.034  1401.212
# 4   5        8.245  1432.002  1434.194  1435.685       NaN

# %%
df2.head(500)
# Out:
#       SN  Station (m)         A         B         C         D
# 0      1        0.000  1431.934  1435.127  1436.161  1401.486
# 1      2        0.684  1431.945  1435.100  1436.169  1401.398
# 2      3        3.223  1431.975  1434.894  1436.115  1401.342
# 3      4        4.368  1431.984  1434.750  1436.034  1401.212
# 4      5        8.245  1432.002  1434.194  1435.685       NaN
# ..   ...          ...       ...       ...       ...       ...
# 495  496      518.934       NaN       NaN       NaN  1357.000
# 496  497      518.934       NaN       NaN       NaN  1357.000
# 497  498      522.469  1397.460  1397.455  1397.463       NaN
# 498  499      522.469       NaN       NaN       NaN  1357.000
# 499  500      526.215  1397.350  1397.345  1397.354       NaN
#
# [500 rows x 6 columns]

# %%
df2 =df2.interpolate()
plt.figure(figsize=(10,6))
plt.plot(df2["Station (m)"],df2["A"],label="Position Left Max WSE")
plt.plot(df2["Station (m)"],df2["B"],label="Position Right Max WSE")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df2["Station (m)"],df2["C"],label="Position Center Max WSE")
plt.plot(df2["Station (m)"],df2["D"],label="Terrain Profile")

# grid
plt.grid(b=True)
# label
plt.title("Water Surface Elevation 'River_Centerline' ",fontweight="bold")
plt.ylabel('Water Surface Elevation(meters)')
plt.xlabel('Station[m]')
# legend
plt.legend(loc='best')
plt.savefig('final/position of breach/wse.jpg',dpi=300)

# %%
# HYDROGRAPH
df1=pd.read_excel('data/position of breach/hydrographs_breachwidth1.xlsx',sheet_name='1')
df2=pd.read_excel('data/position of breach/hydrographs_breachwidth1.xlsx',sheet_name='2')
df3=pd.read_excel('data/position of breach/hydrographs_breachwidth1.xlsx',sheet_name='3')
df4=pd.read_excel('data/position of breach/hydrographs_breachwidth1.xlsx',sheet_name='4')
df5=pd.read_excel('data/position of breach/hydrographs_breachwidth1.xlsx',sheet_name='5')
df6=pd.read_excel('data/position of breach/hydrographs_breachwidth1.xlsx',sheet_name='6')
df7=pd.read_excel('data/position of breach/hydrographs_breachwidth1.xlsx',sheet_name='PH')

# %%
# section 1
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["A"],label="Position Left Flow")
plt.plot(df1["Station (m)"],df1["B"],label="Position Right Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df1["C"],label="Position Center Flow")



# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Position at Location 1 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/position of breach/Sheets/Peakdischarge1.jpg',dpi=300)
# for max value
maxValues = df1.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       160499.422
# B                       160453.359
# C                       160541.313
# dtype: object

# %%
# section 2
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df2["Station (m)"],df2["A"],label="Position Left Flow")
plt.plot(df2["Station (m)"],df2["B"],label="Position Right Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df2["Station (m)"],df2["C"],label="Position Center Flow")



# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Position at Location 2 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/position of breach/Sheets/Peakdischarge2.jpg',dpi=300)
# for max value
maxValues = df2.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       156742.781
# B                       156727.125
# C                       156754.766
# dtype: object

# %%
# section 3
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df3["Station (m)"],df3["A"],label="Position Left Flow")
plt.plot(df3["Station (m)"],df3["B"],label="Position Right Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df3["Station (m)"],df3["C"],label="Position Center Flow")



# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Position at Location 3 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/position of breach/Sheets/Peakdischarge3.jpg',dpi=300)
# for max value
maxValues = df3.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       155820.172
# B                       155804.938
# C                       155824.578
# dtype: object

# %%
# section 4
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df4["Station (m)"],df4["A"],label="Position Left Flow")
plt.plot(df4["Station (m)"],df4["B"],label="Position Right Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df4["Station (m)"],df4["C"],label="Position Center Flow")



# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Position at Location 4 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/position of breach/Sheets/Peakdischarge4.jpg',dpi=300)
# for max value
maxValues = df4.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         155233.0
# B                       155221.766
# C                       155240.141
# dtype: object

# %%
# section 5
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df5["Station (m)"],df5["A"],label="Position Left Flow")
plt.plot(df5["Station (m)"],df5["B"],label="Position Right Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df5["Station (m)"],df5["C"],label="Position Center Flow")



# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Position at Location 5 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/position of breach/Sheets/Peakdischarge5.jpg',dpi=300)
# for max value
maxValues = df5.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       104022.008
# B                       104011.711
# C                       104029.023
# dtype: object

# %%
# section 6
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df6["Station (m)"],df6["A"],label="Position Left Flow")
plt.plot(df6["Station (m)"],df6["B"],label="Position Right Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df6["Station (m)"],df6["C"],label="Position Center Flow")



# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Position at Location 6 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/position of breach/Sheets/Peakdischarge6.jpg',dpi=300)
# for max value
maxValues = df6.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       102782.789
# B                       102772.594
# C                       102789.695
# dtype: object

# %%
# section 3
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df7["Station (m)"],df7["A"],label="Position Left Flow")
plt.plot(df7["Station (m)"],df7["B"],label="Position Right Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df7["Station (m)"],df7["C"],label="Position Center Flow")



# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Position near Power House ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/position of breach/Sheets/Peakdischarge_ph.jpg',dpi=300)
# for max value
maxValues = df7.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       154949.688
# B                       154938.141
# C                        154956.25
# dtype: object
