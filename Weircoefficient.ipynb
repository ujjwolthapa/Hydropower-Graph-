# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import datetime as dt
import matplotlib.dates as md
figure(figsize=(8, 6), dpi=80)
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = "Times New Roman"

# %%
# Weircoefficient
df1=pd.read_excel('data/Weircoefficient/hydrographs_breachwidth1.xlsx',sheet_name='1')
df2=pd.read_excel('data/Weircoefficient/hydrographs_breachwidth1.xlsx',sheet_name='2')
df3=pd.read_excel('data/Weircoefficient/hydrographs_breachwidth1.xlsx',sheet_name='3')
df4=pd.read_excel('data/Weircoefficient/hydrographs_breachwidth1.xlsx',sheet_name='4')
df5=pd.read_excel('data/Weircoefficient/hydrographs_breachwidth1.xlsx',sheet_name='5')
df6=pd.read_excel('data/Weircoefficient/hydrographs_breachwidth1.xlsx',sheet_name='6')
df7=pd.read_excel('data/Weircoefficient/hydrographs_breachwidth1.xlsx',sheet_name='PH')

# %%
df1.head(1000)
# Out:
#        SN         Station (m)         A         B         C         D  \
# 0       1 2022-01-01 00:00:00     0.000     0.000     0.000     0.000
# 1       2 2022-01-01 00:00:30     0.000     0.000     0.000     0.000
# 2       3 2022-01-01 00:01:00     0.000     0.000     0.000     0.000
# 3       4 2022-01-01 00:01:30     0.000     0.000     0.000     0.000
# 4       5 2022-01-01 00:02:00     0.000     0.000     0.000     0.000
# ..    ...                 ...       ...       ...       ...       ...
# 995   996 2022-01-01 08:17:30  2212.697  2212.697  2212.697  2212.697
# 996   997 2022-01-01 08:18:00  2220.104  2220.104  2220.104  2220.104
# 997   998 2022-01-01 08:18:30  2227.542  2227.542  2227.542  2227.542
# 998   999 2022-01-01 08:19:00  2234.977  2234.977  2234.977  2234.977
# 999  1000 2022-01-01 08:19:30  2242.393  2242.393  2242.393  2242.393
#
#             E
# 0       0.000
# 1       0.000
# 2       0.000
# 3       0.000
# 4       0.000
# ..        ...
# 995  2212.697
# ...

# %%
# fullview
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["A"],label="Section 1")
plt.plot(df1["Station (m)"],df2["A"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["A"],label="Section 3")
plt.plot(df1["Station (m)"],df4["A"],label="Section 4")
plt.plot(df1["Station (m)"],df5["A"],label="Section 5")
plt.plot(df1["Station (m)"],df6["A"],label="Section 6")
plt.plot(df1["Station (m)"],df7["A"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Weir Coefficient 3 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/hydrograph(3).jpg',dpi=300)
# for max value
# maxValues1 = df1.max()
# maxValues2 = df2.max()
# maxValues3 = df3.max()
# maxValues4 = df4.max()
# maxValues5 = df5.max()
# maxValues6 = df6.max()
# maxValues7 = df7.max()
 
# print(maxValues1)
# print(maxValues2)
# print(maxValues3)
# print(maxValues4)
# print(maxValues5)
# print(maxValues6)
# print(maxValues7)

# %%
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["B"],label="Section 1")
plt.plot(df1["Station (m)"],df2["B"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["B"],label="Section 3")
plt.plot(df1["Station (m)"],df4["B"],label="Section 4")
plt.plot(df1["Station (m)"],df5["B"],label="Section 5")
plt.plot(df1["Station (m)"],df6["B"],label="Section 6")
plt.plot(df1["Station (m)"],df7["B"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Weir Coefficient 2.6 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Weircoefficient/hydrograph(2.6).jpg',dpi=300)
# for max value
# maxsection1 = df1["B"]
# maxindex1 = maxsection1.idxmax()
# print(maxindex1)
# df1.loc[maxindex1]

# %%
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["C"],label="Section 1")
plt.plot(df1["Station (m)"],df2["C"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["C"],label="Section 3")
plt.plot(df1["Station (m)"],df4["C"],label="Section 4")
plt.plot(df1["Station (m)"],df5["C"],label="Section 5")
plt.plot(df1["Station (m)"],df6["C"],label="Section 6")
plt.plot(df1["Station (m)"],df7["C"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Weir Coefficient 2.7 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Weircoefficient/hydrograph(2.7).jpg',dpi=300)

# %%
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["D"],label="Section 1")
plt.plot(df1["Station (m)"],df2["D"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["D"],label="Section 3")
plt.plot(df1["Station (m)"],df4["D"],label="Section 4")
plt.plot(df1["Station (m)"],df5["D"],label="Section 5")
plt.plot(df1["Station (m)"],df6["D"],label="Section 6")
plt.plot(df1["Station (m)"],df7["D"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Weir Coefficient 2.7 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Weircoefficient/hydrograph(2.8).jpg',dpi=300)

# %%
plt.figure(figsize=(10,6))
plt.plot(df1["Station (m)"],df1["E"],label="Section 1")
plt.plot(df1["Station (m)"],df2["E"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["E"],label="Section 3")
plt.plot(df1["Station (m)"],df4["E"],label="Section 4")
plt.plot(df1["Station (m)"],df5["E"],label="Section 5")
plt.plot(df1["Station (m)"],df6["E"],label="Section 6")
plt.plot(df1["Station (m)"],df7["E"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Weir Coefficient 2.9 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Weircoefficient/hydrograph(2.9).jpg',dpi=300)

# %%
# section 1
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["A"],label="Weir Coefficient 3 Flow ")
plt.plot(df1["Station (m)"],df1["E"],label="Weir Coefficient 2.9 Flow ")
plt.plot(df1["Station (m)"],df1["D"],label="Weir Coefficient 2.8 Flow ")
plt.plot(df1["Station (m)"],df1["C"],label="Weir Coefficient 2.7 Flow ")
plt.plot(df1["Station (m)"],df1["B"],label="Weir Coefficient 2.6 Flow ")
# plt.plot(df1["Station (m)"],df1[""])

# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Weir Coefficient at Location 1 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/Sheets/Peakdischarge1.jpg',dpi=300)
# for max value
maxValues = df1.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       400559.281
# B                         357790.5
# C                       368749.688
# D                        379520.25
# E                       390140.156
# dtype: object

# %%
# section 2
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df2["Station (m)"],df2["A"],label="Weir Coefficient 3 Flow ")
plt.plot(df2["Station (m)"],df2["E"],label="Weir Coefficient 2.9 Flow ")
plt.plot(df2["Station (m)"],df2["D"],label="Weir Coefficient 2.8 Flow ")
plt.plot(df2["Station (m)"],df2["C"],label="Weir Coefficient 2.7 Flow ")
plt.plot(df2["Station (m)"],df2["B"],label="Weir Coefficient 2.6 Flow ")
# plt.plot(df1["Station (m)"],df1[""])

# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Weir Coefficient at Location 2",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/Sheets/Peakdischarge2.jpg',dpi=300)
# for max value
maxValues = df2.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         383041.5
# B                       342414.438
# C                       352905.625
# D                       363169.125
# E                         373196.0
# dtype: object

# %%
# section 3
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df3["Station (m)"],df3["A"],label="Weir Coefficient 3 Flow ")
plt.plot(df3["Station (m)"],df3["E"],label="Weir Coefficient 2.9 Flow ")
plt.plot(df3["Station (m)"],df3["D"],label="Weir Coefficient 2.8 Flow ")
plt.plot(df3["Station (m)"],df3["C"],label="Weir Coefficient 2.7 Flow ")
plt.plot(df3["Station (m)"],df3["B"],label="Weir Coefficient 2.6 Flow ")
# plt.plot(df1["Station (m)"],df1[""])

# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Weir Coefficient at Location 3 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/Sheets/Peakdischarge3.jpg',dpi=300)
# for max value
maxValues = df3.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                        380151.25
# B                       339951.344
# C                       350029.531
# D                       359993.438
# E                       370185.469
# dtype: object

# %%
# section 4
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df4["Station (m)"],df4["A"],label="Weir Coefficient 3 Flow ")
plt.plot(df4["Station (m)"],df4["E"],label="Weir Coefficient 2.9 Flow ")
plt.plot(df4["Station (m)"],df4["D"],label="Weir Coefficient 2.8 Flow ")
plt.plot(df4["Station (m)"],df4["C"],label="Weir Coefficient 2.7 Flow ")
plt.plot(df4["Station (m)"],df4["B"],label="Weir Coefficient 2.6 Flow ")
# plt.plot(df1["Station (m)"],df1[""])

# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Weir Coefficient at Location 4",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/Sheets/Peakdischarge4.jpg',dpi=300)
# for max value
maxValues = df4.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         376794.5
# B                       337307.125
# C                       347144.344
# D                       357159.625
# E                       367096.188
# dtype: object

# %%
# section 5
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df5["Station (m)"],df5["A"],label="Weir Coefficient 3 Flow ")
plt.plot(df5["Station (m)"],df5["E"],label="Weir Coefficient 2.9 Flow ")
plt.plot(df5["Station (m)"],df5["D"],label="Weir Coefficient 2.8 Flow ")
plt.plot(df5["Station (m)"],df5["C"],label="Weir Coefficient 2.7 Flow ")
plt.plot(df5["Station (m)"],df5["B"],label="Weir Coefficient 2.6 Flow ")
# plt.plot(df1["Station (m)"],df1[""])

# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Weir Coefficient at Location 5",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/Sheets/Peakdischarge5.jpg',dpi=300)
# for max value
maxValues = df5.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       222101.875
# B                       205262.797
# C                       209646.516
# D                       213905.625
# E                       218063.281
# dtype: object

# %%
# section 6
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df6["Station (m)"],df6["A"],label="Weir Coefficient 3 Flow ")
plt.plot(df6["Station (m)"],df6["E"],label="Weir Coefficient 2.9 Flow ")
plt.plot(df6["Station (m)"],df6["D"],label="Weir Coefficient 2.8 Flow ")
plt.plot(df6["Station (m)"],df6["C"],label="Weir Coefficient 2.7 Flow ")
plt.plot(df6["Station (m)"],df6["B"],label="Weir Coefficient 2.6 Flow ")
# plt.plot(df1["Station (m)"],df1[""])

# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Weir Coefficient at Location 6",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/Sheets/Peakdischarge6.jpg',dpi=300)
# for max value
maxValues = df6.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       220208.375
# B                       203597.344
# C                       207909.172
# D                       212128.125
# E                       216228.453
# dtype: object

# %%
# section 6
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df7["Station (m)"],df7["A"],label="Weir Coefficient 3 Flow ")
plt.plot(df7["Station (m)"],df7["E"],label="Weir Coefficient 2.9 Flow ")
plt.plot(df7["Station (m)"],df7["D"],label="Weir Coefficient 2.8 Flow ")
plt.plot(df7["Station (m)"],df7["C"],label="Weir Coefficient 2.7 Flow ")
plt.plot(df7["Station (m)"],df7["B"],label="Weir Coefficient 2.6 Flow ")
# plt.plot(df1["Station (m)"],df1[""])

# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Weir Coefficient at Location near Power House",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Weircoefficient/Sheets/Peakdischarge_ph.jpg',dpi=300)
# for max value
maxValues = df7.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       375769.125
# B                       336504.969
# C                       346711.969
# D                       356636.375
# E                       366326.531
# dtype: object
