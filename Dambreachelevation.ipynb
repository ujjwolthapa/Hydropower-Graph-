# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import datetime as dt
import matplotlib.dates as md
figure(figsize=(8, 6), dpi=80)
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = "Times New Roman"

# %%
df1=pd.read_excel('data/Dambreachelevation/hydrographs_breachwidth1.xlsx',sheet_name='1')
df2=pd.read_excel('data/Dambreachelevation/hydrographs_breachwidth1.xlsx',sheet_name='2')
df3=pd.read_excel('data/Dambreachelevation/hydrographs_breachwidth1.xlsx',sheet_name='3')
df4=pd.read_excel('data/Dambreachelevation/hydrographs_breachwidth1.xlsx',sheet_name='4')
df5=pd.read_excel('data/Dambreachelevation/hydrographs_breachwidth1.xlsx',sheet_name='5')
df6=pd.read_excel('data/Dambreachelevation/hydrographs_breachwidth1.xlsx',sheet_name='6')
df7=pd.read_excel('data/Dambreachelevation/hydrographs_breachwidth1.xlsx',sheet_name='PH')

# %%
df1.head(1000)
# Out:
#        SN         Station (m)         A         B          C           D  \
# 0       1 2022-01-01 00:00:00     0.000     0.000      0.000       0.000
# 1       2 2022-01-01 00:00:30     0.000     0.000      0.000       0.000
# 2       3 2022-01-01 00:01:00     0.000     0.000      0.000       0.000
# 3       4 2022-01-01 00:01:30     0.000     0.000      0.000       0.000
# 4       5 2022-01-01 00:02:00   631.442     0.000      0.000       0.000
# ..    ...                 ...       ...       ...        ...         ...
# 995   996 2022-01-01 08:17:30  5154.269  5465.955  10077.626  229094.719
# 996   997 2022-01-01 08:18:00  5157.008  5462.610   9967.210  221909.922
# 997   998 2022-01-01 08:18:30  5159.530  5459.228   9859.719  215022.281
# 998   999 2022-01-01 08:19:00  5162.324  5456.069   9754.992  208420.859
# 999  1000 2022-01-01 08:19:30  5164.836  5452.827   9652.747  202093.250
#
#             E
# 0       0.000
# 1       0.000
# 2       0.000
# 3       0.000
# ...

# %%
# fullview
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["A"],label="Section 1")
plt.plot(df1["Station (m)"],df2["A"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["A"],label="Section 3")
plt.plot(df1["Station (m)"],df4["A"],label="Section 4")
plt.plot(df1["Station (m)"],df5["A"],label="Section 5")
plt.plot(df1["Station (m)"],df6["A"],label="Section 6")
plt.plot(df1["Station (m)"],df7["A"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Dam Breach Elevation 1580 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
plt.savefig('final/BreachWidth/hydrograph(247.5).jpg',dpi=300)
# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/hydrograph(1580).jpg',dpi=300)
# for max value
maxValues = df4.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       295925.688
# B                       306381.625
# C                       315984.938
# D                       333832.625
# E                       342477.875
# dtype: object

# %%
# fullview 1584
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["B"],label="Section 1")
plt.plot(df1["Station (m)"],df2["B"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["B"],label="Section 3")
plt.plot(df1["Station (m)"],df4["B"],label="Section 4")
plt.plot(df1["Station (m)"],df5["B"],label="Section 5")
plt.plot(df1["Station (m)"],df6["B"],label="Section 6")
plt.plot(df1["Station (m)"],df7["B"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Dam Breach Elevation 1582 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Dambreachelevation/hydrograph(1582).jpg',dpi=300)
# for max value
maxsection1 = df1["A"]
maxindex1 = maxsection1.idxmax()

df1.loc[maxindex1]
# maxValues = df4.max()
 
# print(maxValues)
# Out:
# SN                              31
# Station (m)    2022-01-01 00:15:00
# A                         319300.0
# B                              0.0
# C                              0.0
# D                              0.0
# E                              0.0
# Name: 30, dtype: object

# %%
# fullview 148
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["C"],label="Section 1")
plt.plot(df1["Station (m)"],df2["C"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["C"],label="Section 3")
plt.plot(df1["Station (m)"],df4["C"],label="Section 4")
plt.plot(df1["Station (m)"],df5["C"],label="Section 5")
plt.plot(df1["Station (m)"],df6["C"],label="Section 6")
plt.plot(df1["Station (m)"],df7["C"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Dam Breach Elevation 1584 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Dambreachelevation/hydrograph(1584).jpg',dpi=300)

# %%
# fullview for 
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["D"],label="Section 1")
plt.plot(df1["Station (m)"],df2["D"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["D"],label="Section 3")
plt.plot(df1["Station (m)"],df4["D"],label="Section 4")
plt.plot(df1["Station (m)"],df5["D"],label="Section 5")
plt.plot(df1["Station (m)"],df6["D"],label="Section 6")
plt.plot(df1["Station (m)"],df7["D"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Dam Breach Elevation 1586 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Dambreachelevation/hydrograph(1586).jpg',dpi=300)

# %%
# fullview for 0.3
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["E"],label="Section 1")
plt.plot(df1["Station (m)"],df2["E"],label="Section 2")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df3["E"],label="Section 3")
plt.plot(df1["Station (m)"],df4["E"],label="Section 4")
plt.plot(df1["Station (m)"],df5["E"],label="Section 5")
plt.plot(df1["Station (m)"],df6["E"],label="Section 6")
plt.plot(df1["Station (m)"],df7["E"],label="Section near Powerhouse")

# grid
plt.grid(b=True)
# label
plt.title("Flow hydrograph at different sections downstream with Dam Breach Elevation 1588 Flow",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Time')
# legend
plt.legend(loc='best')
plt.savefig('final/Dambreachelevation/hydrograph(1588).jpg',dpi=300)

# %%
# section 1
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df1["Station (m)"],df1["A"],label="Dam Breach Elevation 1580 Flow")
plt.plot(df1["Station (m)"],df1["B"],label="Dam Breach Elevation 1582 Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df1["Station (m)"],df1["C"],label="Dam Breach Elevation 1584 Flow")
plt.plot(df1["Station (m)"],df1["D"],label="Dam Breach Elevation 1586 Flow")
plt.plot(df1["Station (m)"],df1["E"],label="Dam Breach Elevation 1588 Flow")


# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Elevation at Location 1 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/Sheets/Peakdischarge1.jpg',dpi=300)
# for max value
maxValues = df1.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         319300.0
# B                       330179.156
# C                       339538.781
# D                       355925.438
# E                       363311.531
# dtype: object

# %%
# section 2
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df2["Station (m)"],df2["A"],label="Dam Breach Elevation 1580 Flow")
plt.plot(df2["Station (m)"],df2["B"],label="Dam Breach Elevation 1582 Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df2["Station (m)"],df2["C"],label="Dam Breach Elevation 1584 Flow")
plt.plot(df2["Station (m)"],df2["D"],label="Dam Breach Elevation 1586 Flow")
plt.plot(df2["Station (m)"],df2["E"],label="Dam Breach Elevation 1588 Flow")


# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Elevation at Location 2",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/Sheets/Peakdischarge2.jpg',dpi=300)
# for max value
maxValues = df1.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         319300.0
# B                       330179.156
# C                       339538.781
# D                       355925.438
# E                       363311.531
# dtype: object

# %%
# section 3
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df3["Station (m)"],df3["A"],label="Dam Breach Elevation 1580 Flow")
plt.plot(df3["Station (m)"],df3["B"],label="Dam Breach Elevation 1582 Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df3["Station (m)"],df3["C"],label="Dam Breach Elevation 1584 Flow")
plt.plot(df3["Station (m)"],df3["D"],label="Dam Breach Elevation 1586 Flow")
plt.plot(df3["Station (m)"],df3["E"],label="Dam Breach Elevation 1588 Flow")


# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Elevation at Location 3",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/Sheets/Peakdischarge3.jpg',dpi=300)
# for max value
maxValues = df1.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         319300.0
# B                       330179.156
# C                       339538.781
# D                       355925.438
# E                       363311.531
# dtype: object

# %%
# section 4
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df4["Station (m)"],df4["A"],label="Dam Breach Elevation 1580 Flow")
plt.plot(df4["Station (m)"],df4["B"],label="Dam Breach Elevation 1582 Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df4["Station (m)"],df4["C"],label="Dam Breach Elevation 1584 Flow")
plt.plot(df4["Station (m)"],df4["D"],label="Dam Breach Elevation 1586 Flow")
plt.plot(df4["Station (m)"],df4["E"],label="Dam Breach Elevation 1588 Flow")


# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Elevation at Location 4",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/Sheets/Peakdischarge4.jpg',dpi=300)
# for max value
maxValues = df1.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         319300.0
# B                       330179.156
# C                       339538.781
# D                       355925.438
# E                       363311.531
# dtype: object

# %%
# section 5
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df5["Station (m)"],df5["A"],label="Dam Breach Elevation 1580 Flow")
plt.plot(df5["Station (m)"],df5["B"],label="Dam Breach Elevation 1582 Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df5["Station (m)"],df5["C"],label="Dam Breach Elevation 1584 Flow")
plt.plot(df5["Station (m)"],df5["D"],label="Dam Breach Elevation 1586 Flow")
plt.plot(df5["Station (m)"],df5["E"],label="Dam Breach Elevation 1588 Flow")


# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Elevation at Location 5 ",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/Sheets/Peakdischarge5.jpg',dpi=300)
# for max value
maxValues = df5.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       171617.188
# B                       179256.313
# C                       186757.203
# D                       195964.578
# E                       206460.516
# dtype: object

# %%
# section 6
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df6["Station (m)"],df6["A"],label="Dam Breach Elevation 1580 Flow")
plt.plot(df6["Station (m)"],df6["B"],label="Dam Breach Elevation 1582 Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df6["Station (m)"],df6["C"],label="Dam Breach Elevation 1584 Flow")
plt.plot(df6["Station (m)"],df6["D"],label="Dam Breach Elevation 1586 Flow")
plt.plot(df6["Station (m)"],df6["E"],label="Dam Breach Elevation 1588 Flow")


# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Elevation at Location 6",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/Sheets/Peakdischarge6.jpg',dpi=300)
# for max value
maxValues = df6.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                       169758.734
# B                       177884.234
# C                       185482.063
# D                       194518.063
# E                       204772.766
# dtype: object

# %%
# section 6
#time vs all parameters
# fullview
plt.figure(figsize=(10,6))

plt.plot(df7["Station (m)"],df7["A"],label="Dam Breach Elevation 1580 Flow")
plt.plot(df7["Station (m)"],df7["B"],label="Dam Breach Elevation 1582 Flow")
# plt.plot(df1["Station (m)"],df1[""])
plt.plot(df7["Station (m)"],df7["C"],label="Dam Breach Elevation 1584 Flow")
plt.plot(df7["Station (m)"],df7["D"],label="Dam Breach Elevation 1586 Flow")
plt.plot(df7["Station (m)"],df7["E"],label="Dam Breach Elevation 1588 Flow")


# grid
plt.grid(b=True)
# label
plt.title("Peak Discharge for Different Values of Dam Breach Elevation at Location near Power House",fontweight="bold")
plt.ylabel('Flow(CMS)')
plt.xlabel('Date/Time')

# legend
plt.legend(loc='best')

plt.savefig('final/Dambreachelevation/Sheets/Peakdischarge_ph.jpg',dpi=300)
# for max value
maxValues = df7.max()
 
print(maxValues)
# Out:
# SN                            3841
# Station (m)    2022-01-02 08:00:00
# A                         295186.0
# B                       305898.844
# C                       315270.125
# D                       333196.531
# E                         342015.0
# dtype: object
